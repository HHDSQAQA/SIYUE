# %% [markdown]
# # Clone repository

# %%
# !git clone https://github.com/kagura114/vits.git
# %cd vits
# !pip install -r requirements.txt
# !sudo apt-get update
# !sudo apt-get install espeak -y

# %% [markdown]
# # Copy Dataset

# %%
# !featurize dataset download 365f400e-da32-4227-be34-c5c867c8d44a
# !cp -r /home/featurize/data/wavs /home/featurize/vits/
# !mv /home/featurize/vits/wavs /home/featurize/vits/wav

# %% [markdown]
# # Alignment

# %%
# %cd monotonic_align
# !python setup.py build_ext --inplace
# %cd ..

# %% [markdown]
# # Train

# %%
# !python train_ms.py -c configs/japanese_ss_base2.json.json -m japanese_ss_base2.json
